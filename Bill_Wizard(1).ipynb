# %% [markdown]
# <a href="https://colab.research.google.com/github/KARTIKAY2003/Project/blob/main/Bill_Wizard(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tesseract
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 MB 15.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tesseract: filename=tesseract-0.1.3-py3-none-any.whl size=45562552 sha256=4799ff2f9e16cead8d5248ae2fc5ac08794fea7ed47c3c5447f62f06c481448c
#   Stored in directory: /root/.cache/pip/wheels/71/c9/aa/698c579693e83fdda9ad6d6f0d8f61ed986e27925ef576f109
# Successfully built tesseract
# ...

# %%
# !pip install opencv-python

# %%
# !pip install pytesseract

# %%
# !pip install scikit-learn pandas

# %%
# !apt-get install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 49 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 2s (2,900 kB/s)
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 123599 files and directories currently installed.)
# ...

# %%
# !pip install opencv-python-headless pytesseract scikit-learn pandas

# %%
import cv2
import pytesseract
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import json
import pandas as pd

# %%
def capture_video():
    cap = cv2.VideoCapture(0)  # Capture video from webcam
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        cv2.imshow('Invoice Capture', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
    return frame  # Return last captured frame (for demo purposes)

# Capture a frame
invoice_frame = capture_video()

# %%
def capture_video():
    cap = cv2.VideoCapture(0)  # Capture video from webcam

    while True:
        ret, frame = cap.read()
        if not ret:
            print("Error: Missing frame") # Added print statement to check if frames are being read
            break

        cv2.imshow('Invoice Capture', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
    return frame  # Return last captured frame

# %%
import re

def detect_total_amount(text):
    pattern = r'Total\s*:\s*\$?\s*([0-9]+(?:\.[0-9]{1,2})?)'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(1)
    return None

total_amount = detect_total_amount(invoice_text)
print(f"Total Amount Detected: {total_amount}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-af8d607071fc> in <cell line: 10>()
#       8     return None
#       9
# ---> 10 total_amount = detect_total_amount(invoice_text)
#      11 print(f"Total Amount Detected: {total_amount}")
#
# NameError: name 'invoice_text' is not defined

# %%
import cv2
import pytesseract
import re
import numpy as np

# Function to capture video frames from webcam
def capture_video():
    cap = cv2.VideoCapture(0)  # Capture video from webcam
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        cv2.imshow('Invoice Capture', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
    return frame  # Return last captured frame (for demo purposes)

# Function to preprocess the image
def preprocess_image(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
    return binary

# Function to extract text from the image using Tesseract
def extract_text_from_image(image):
    processed_image = preprocess_image(image)
    text = pytesseract.image_to_string(processed_image)
    return text

# Function to detect total amount using regex
def detect_total_amount(text):
    pattern = r'Total\s*:\s*\$?\s*([0-9]+(?:\.[0-9]{1,2})?)'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(1)
    return None

# Capture a frame from the video (or load from file)
invoice_frame = capture_video()

# Extract text from the captured frame
invoice_text = extract_text_from_image(invoice_frame)

# Check if the text was successfully extracted
if invoice_text:
    print("Extracted Text:\n", invoice_text)

    # Detect total amount from the extracted text
    total_amount = detect_total_amount(invoice_text)
    print(f"Total Amount Detected: {total_amount}")
else:
    print("No text found in the invoice.")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-15-79d74e285a8b> in <cell line: 47>()
#      45
#      46 # Extract text from the captured frame
# ---> 47 invoice_text = extract_text_from_image(invoice_frame)
#      48
#      49 # Check if the text was successfully extracted
#
# <ipython-input-15-79d74e285a8b> in extract_text_from_image(image)
#      29 # Function to extract text from the image using Tesseract
#      30 def extract_text_from_image(image):
# ---> 31     processed_image = preprocess_image(image)
#      32     text = pytesseract.image_to_string(processed_image)
#      33     return text
#
# <ipython-input-15-79d74e285a8b> in preprocess_image(image)
#      23 # Function to preprocess the image
#      24 def preprocess_image(image):
# ---> 25     gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# ...

# %%
# prompt: generate the code for please capture the video frames using opencv, analyze, the frames to extract the relevant portions of the invoice(total amount, total tax, item list

import cv2
import pytesseract
import numpy as np
import re

# Function to capture video frames from webcam
def capture_video():
    cap = cv2.VideoCapture(0)  # Capture video from webcam
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        cv2.imshow('Invoice Capture', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
    return frame  # Return last captured frame (for demo purposes)

# Function to preprocess the image
def preprocess_image(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
    return binary

# Function to extract text from the image using Tesseract
def extract_text_from_image(image):
    processed_image = preprocess_image(image)
    text = pytesseract.image_to_string(processed_image)
    return text

# Function to detect total amount using regex
def detect_total_amount(text):
    pattern = r'Total\s*:\s*\$?\s*([0-9]+(?:\.[0-9]{1,2})?)'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(1)
    return None

# Function to detect total tax using regex
def detect_total_tax(text):
    pattern = r'(Total Tax|Sales Tax)\s*:\s*\$?\s*([0-9]+(?:\.[0-9]{1,2})?)'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(2)
    return None

# Function to detect item list using regex
def detect_item_list(text):
    # Implement regex pattern to extract item list
    # This is a simple example, you may need to adjust it based on your invoice format
    pattern = r'(\d+\.\s+)(.*?)\s+(\$[0-9]+(?:\.[0-9]{1,2})?)'
    matches = re.findall(pattern, text, re.IGNORECASE)
    if matches:
        return matches
    return None


# Capture a frame from the video (or load from file)
invoice_frame = capture_video()

# Extract text from the captured frame
invoice_text = extract_text_from_image(invoice_frame)

# Check if the text was successfully extracted
if invoice_text:
    print("Extracted Text:\n", invoice_text)

    # Detect total amount from the extracted text
    total_amount = detect_total_amount(invoice_text)
    print(f"Total Amount Detected: {total_amount}")

    # Detect total tax from the extracted text
    total_tax = detect_total_tax(invoice_text)
    print(f"Total Tax Detected: {total_tax}")

    # Detect item list from the extracted text
    item_list = detect_item_list(invoice_text)
    if item_list:
        print("Item List Detected:")
        for item in item_list:
            print(item)
    else:
        print("No item list detected.")
else:
    print("No text found in the invoice.")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-16-d46a2354130b> in <cell line: 68>()
#      66
#      67 # Extract text from the captured frame
# ---> 68 invoice_text = extract_text_from_image(invoice_frame)
#      69
#      70 # Check if the text was successfully extracted
#
# <ipython-input-16-d46a2354130b> in extract_text_from_image(image)
#      31 # Function to extract text from the image using Tesseract
#      32 def extract_text_from_image(image):
# ---> 33     processed_image = preprocess_image(image)
#      34     text = pytesseract.image_to_string(processed_image)
#      35     return text
#
# <ipython-input-16-d46a2354130b> in preprocess_image(image)
#      25 # Function to preprocess the image
#      26 def preprocess_image(image):
# ---> 27     gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# ...

# %%
import cv2
import pytesseract
import numpy as np
import re

# Function to capture video frames from webcam
def capture_video():
    cap = cv2.VideoCapture(0)  # Capture video from webcam
    if not cap.isOpened():
        raise IOError("Cannot open webcam") # Raise error if webcam cannot be opened
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        cv2.imshow('Invoice Capture', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
    return frame  # Return last captured frame (for demo purposes)

# Function to preprocess the image
def preprocess_image(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
    return binary

# Function to extract text from the image using Tesseract
def extract_text_from_image(image):
    processed_image = preprocess_image(image)
    text = pytesseract.image_to_string(processed_image)
    return text

# Function to detect total amount using regex
def detect_total_amount(text):
    pattern = r'Total\s*:\s*\$?\s*([0-9]+(?:\.[0-9]{1,2})?)'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(1)
    return None

# Function to detect total tax using regex
def detect_total_tax(text):
    pattern = r'(Total Tax|Sales Tax)\s*:\s*\$?\s*([0-9]+(?:\.[0-9]{1,2})?)'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(2)
    return None

# Function to detect item list using regex
def detect_item_list(text):
    # Implement regex pattern to extract item list
    # This is a simple example, you may need to adjust it based on your invoice format
    pattern = r'(\d+\.\s+)(.*?)\s+(\$[0-9]+(?:\.[0-9]{1,2})?)'
    matches = re.findall(pattern, text, re.IGNORECASE)
    if matches:
        return matches
    return None


# Capture a frame from the video (or load from file)
invoice_frame = capture_video()

# Check if a frame was captured
if invoice_frame is not None:
    # Extract text from the captured frame
    invoice_text = extract_text_from_image(invoice_frame)

    # Check if the text was successfully extracted
    if invoice_text:
        print("Extracted Text:\n", invoice_text)

        # Detect total amount from the extracted text
        total_amount = detect_total_amount(invoice_text)
        print(f"Total Amount Detected: {total_amount}")

        # Detect total tax from the extracted text
        total_tax = detect_total_tax(invoice_text)
        print(f"Total Tax Detected: {total_tax}")

        # Detect item list from the extracted text
        item_list = detect_item_list(invoice_text)
        if item_list:
            print("Item List Detected:")
            for item in item_list:
                print(item)
        else:
            print("No item list detected.")
    else:
        print("No text found in the invoice.")
else:
    print("No frame captured.") # Print message if no frame was captured
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-1c6d2b803c25> in <cell line: 65>()
#      63
#      64 # Capture a frame from the video (or load from file)
# ---> 65 invoice_frame = capture_video()
#      66
#      67 # Check if a frame was captured
#
# <ipython-input-17-1c6d2b803c25> in capture_video()
#       8     cap = cv2.VideoCapture(0)  # Capture video from webcam
#       9     if not cap.isOpened():
# ---> 10         raise IOError("Cannot open webcam") # Raise error if webcam cannot be opened
#      11     while True:
#      12         ret, frame = cap.read()
#
# OSError: Cannot open webcam

# %%
#For image
from google.colab import files
import cv2
import pytesseract
import re
import numpy as np
from PIL import Image

# Function to preprocess the image
def preprocess_image(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
    return binary

# Function to extract text from the image using Tesseract
def extract_text_from_image(image):
    processed_image = preprocess_image(image)
    text = pytesseract.image_to_string(processed_image)
    return text

# Function to detect total amount using regex
def detect_total_amount(text):
    pattern = r'Total\s*:\s*\$?\s*([0-9]+(?:\.[0-9]{1,2})?)'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(1)
    return None

# Upload the image
uploaded = files.upload()

# Load the uploaded image file
for filename in uploaded.keys():
    image = cv2.imread(filename)

# Extract text from the uploaded image
invoice_text = extract_text_from_image(image)

# Check if the text was successfully extracted
if invoice_text:
    print("Extracted Text:\n", invoice_text)

    # Detect total amount from the extracted text
    total_amount = detect_total_amount(invoice_text)
    print(f"Total Amount Detected: {total_amount}")
else:
    print("No text found in the invoice.")
# Out:
#      <input type="file" id="files-59ceddb4-ee90-4871-be7c-4ccc9a9b32c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-59ceddb4-ee90-4871-be7c-4ccc9a9b32c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# For video
from google.colab import files
import cv2
import pytesseract
import re
import numpy as np

# Function to preprocess the image
def preprocess_image(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
    return binary

# Function to extract text from the image using Tesseract
def extract_text_from_image(image):
    processed_image = preprocess_image(image)
    text = pytesseract.image_to_string(processed_image)
    return text

# Function to detect total amount using regex
def detect_total_amount(text):
    pattern = r'Total\s*:\s*\$?\s*([0-9]+(?:\.[0-9]{1,2})?)'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(1)
    return None

# Upload the video
uploaded = files.upload()

# Load the uploaded video
for filename in uploaded.keys():
    video = cv2.VideoCapture(filename)

# Capture a frame from the video
ret, frame = video.read()
if ret:
    # Extract text from the captured frame
    invoice_text = extract_text_from_image(frame)

    # Check if the text was successfully extracted
    if invoice_text:
        print("Extracted Text:\n", invoice_text)

        # Detect total amount from the extracted text
        total_amount = detect_total_amount(invoice_text)
        print(f"Total Amount Detected: {total_amount}")
    else:
        print("No text found in the invoice.")
else:
    print("Failed to read video frame.")
# Out:
#      <input type="file" id="files-12228686-163e-4ead-a070-bf4f7cdef04e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12228686-163e-4ead-a070-bf4f7cdef04e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: generate the code to apply OCR to extract the total bill amount and other relevant text from the invoice and add that total amount is amount in words

import cv2
import pytesseract
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import json
import pandas as pd
import re
from google.colab import files
from PIL import Image
import inflect

# !pip install tesseract
# !pip install opencv-python
# !pip install pytesseract
# !pip install scikit-learn pandas
# !apt-get install tesseract-ocr
# !pip install opencv-python-headless pytesseract scikit-learn pandas


# Function to preprocess the image
def preprocess_image(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
    return binary

# Function to extract text from the image using Tesseract
def extract_text_from_image(image):
    processed_image = preprocess_image(image)
    text = pytesseract.image_to_string(processed_image)
    return text

# Function to detect total amount using regex
def detect_total_amount(text):
    pattern = r'Total\s*:\s*\$?\s*([0-9]+(?:\.[0-9]{1,2})?)'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(1)
    return None

# Function to convert a number to words
def number_to_words(number):
    p = inflect.engine()
    try:
        return p.number_to_words(number)
    except:
        return "Could not convert to words"


# Upload the image
uploaded = files.upload()

# Load the uploaded image file
for filename in uploaded.keys():
    image = cv2.imread(filename)

# Extract text from the uploaded image
invoice_text = extract_text_from_image(image)

# Check if the text was successfully extracted
if invoice_text:
    print("Extracted Text:\n", invoice_text)

    # Detect total amount from the extracted text
    total_amount = detect_total_amount(invoice_text)
    if total_amount:
        print(f"Total Amount Detected: {total_amount}")
        total_amount_in_words = number_to_words(float(total_amount))
        print(f"Total Amount in Words: {total_amount_in_words}")
    else:
        print("Could not detect total amount.")
else:
    print("No text found in the invoice.")
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ...
#      <input type="file" id="files-092c855e-2ed1-4864-a65c-a1e2ce257b51" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-092c855e-2ed1-4864-a65c-a1e2ce257b51">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# ...

# %%
#Recognizing text from the images using OCR
def pdf2txt(PDF_file):
    pytesseract.pytesseract.tesseract_cmd = r"f/content/invoice.pdf"
    pytesseract.pytesseract.tesseract_cmd = tesseract_loc
    PDF_file=PDF_file
    pdfs = glob.glob(PDF_file)
    text=''
    for pdf_path in pdfs:
        pages = convert_from_path(pdf_path, 500,poppler_path=poppler_path)

        for pageNum,imgBlob in enumerate(pages):
            filename = pdf_path[:-4]+'_page'+str(pageNum)+'.jpg'
            # Save the image of the page in system
            imgBlob.save(filename, 'JPEG')
            text = text+pytesseract.image_to_string(filename,lang='eng',config='--psm 6')
    return(text)

# %%
# =============================================================================
# This function will extract the information from the text generated from the pdf.
# I'm using a corrosponding regex which is save with the same name of the pdf file.
# In future we can create template mapping for the same structured pdf files.
# =============================================================================

def extract_info(PDF_file,text):
    try:
        with open (PDF_file.split('/')[-1:][0][:-4]+".txt", "r") as myfile:
            data=myfile.readlines()
    except FileNotFoundError:
        print("Wrong file or template missing")
        return

    values_dict={}

    if (re.findall('REFORAWING|REFDRAWING',text)):
        print('Document Type: Engineering Drawing')
        try:
            values_dict['Job Number']=re.findall(data[0][:-1], text)[0]
        except:
            values_dict['Job  Number']=re.findall(data[0][:-1], text)
        try:
            values_dict['Pipe Class']=re.findall(data[1][:-1], text)[0]
        except:
            values_dict['Pipe Class']=re.findall(data[1][:-1], text)

    elif ((re.findall('Invoice',text))):
        print('Document Type: Invoice')
        try:
            values_dict['Invoice Number']=re.findall(data[0][:-1], text)[0]
        except:
            values_dict['Invoice Number']=re.findall(data[0][:-1], text)
        try:
            values_dict['Invoice Date']=re.findall(data[1][:-1], text)[0]
        except:
            values_dict['Invoice Date']=re.findall(data[1][:-1], text)
        try:
            values_dict['Invoice Amount']=re.findall(data[2], text)[0]
        except:
            values_dict['Invoice Amount']=re.findall(data[2], text)
    else:
        print('Unknown')

#Writing json file
    print(values_dict)
    with open (PDF_file.split('/')[-1:][0][:-4]+".json", "w") as myfile:
        myfile.write(json.dumps(values_dict))

def main(args=None):
    try:
        #pdf2txt('BD1-1421.pdf')
        print(args[0])
        text=pdf2txt(args[0])
        extract_info(args[0],text)
    except:
        print('Usage: pdf_extract.py <pdf file name>')

# %%
# Install required packages
# !pip install scikit-learn pandas xmltodict

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Sample Data: Text extracted from invoices and their corresponding categories
# In a real scenario, you will need a dataset of invoice texts labeled with categories
data = {
    "text": [
        "Invoice for groceries: apples, bananas, milk, bread",
        "Electronics: TV, laptop, mobile phone",
        "Services: car repair, plumbing, electrician",
        "Invoice for groceries: vegetables, fruits, rice",
        "Electronics: washing machine, headphones",
        "Invoice for services: cleaning, home maintenance"
    ],
    "category": [
        "groceries", "electronics", "services", "groceries", "electronics", "services"
    ]
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Step 1: Extract text and labels
X = df['text']  # Features: Invoice text
y = df['category']  # Labels: Invoice categories

# Step 2: Convert text to numerical features using TF-IDF
vectorizer = TfidfVectorizer()
X_tfidf = vectorizer.fit_transform(X)

# Step 3: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# Step 4: Train a machine learning model (Logistic Regression or SVM)
# Using Logistic Regression
model = LogisticRegression()
model.fit(X_train, y_train)

# For SVM, you can uncomment the following line:
model1 = SVC(kernel='linear')
model1.fit(X_train, y_train)

# Step 5: Test the model
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy * 100:.2f}%")

y_pred1 = model1.predict(X_test)
accuracy1 = accuracy_score(y_test, y_pred1)
print(f"Model Accuracy: {accuracy1 * 100:.2f}%")

# Step 6: Categorize a new invoice
new_invoice_text = "Invoice for groceries: cereal, milk, bread"
new_invoice_tfidf = vectorizer.transform([new_invoice_text])  # Transform the new invoice text
category = model.predict(new_invoice_tfidf)[0]  # Predict the category
print(f"Predicted Category: {category}")
# Out:
# Model Accuracy: 0.00%
# Model Accuracy: 0.00%
# Predicted Category: services

# %%
import json
import xmltodict

# Function to export data in JSON format
def export_to_json(data, filename="invoice_data.json"):
    with open(filename, 'w') as json_file:
        json.dump(data, json_file, indent=4)
    print(f"Data exported to {filename}")

# Function to export data in CSV format
def export_to_csv(data, filename="invoice_data.csv"):
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False)
    print(f"Data exported to {filename}")

# Function to export data in XML format
def export_to_xml(data, filename="invoice_data.xml"):
    with open(filename, 'w') as xml_file:
        xml_data = xmltodict.unparse({"Invoices": {"Invoice": data}}, pretty=True)
        xml_file.write(xml_data)
    print(f"Data exported to {filename}")

# Prepare a sample result dictionary for export
result_data = {
    "invoice_text": new_invoice_text,
    "detected_amount": "50.00",  # Placeholder for amount (you can detect this using earlier OCR step)
    "predicted_category": category
}

# Export to JSON
export_to_json(result_data)

# Export to CSV
export_to_csv([result_data])

# Export to XML
export_to_xml([result_data])

# %%
# prompt: generate the code to apply OCR to extract the total bill amount and other relevant text from the invoice

# !pip install opencv-python-headless pytesseract
import cv2
import pytesseract
from google.colab import files

# Function to preprocess the image
def preprocess_image(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
    return binary

# Function to extract text from the image using Tesseract
def extract_text_from_image(image):
    processed_image = preprocess_image(image)
    text = pytesseract.image_to_string(processed_image)
    return text

# Function to detect total amount using regex
def detect_total_amount(text):
    pattern = r'Total\s*:\s*\$?\s*([0-9]+(?:\.[0-9]{1,2})?)'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(1)
    return None

# Upload the image
uploaded = files.upload()

# Load the uploaded image file
for filename in uploaded.keys():
    # Added error handling for image loading
    try:
        image = cv2.imread(filename)
        if image is None:
            raise Exception(f"Failed to load image: {filename}")
    except Exception as e:
        print(f"Error: {e}")
        continue  # Skip to the next file if there's an error

    # Extract text from the uploaded image
    invoice_text = extract_text_from_image(image)

    # Check if the text was successfully extracted
    if invoice_text:
        print("Extracted Text:\n", invoice_text)

        # Detect total amount from the extracted text
        total_amount = detect_total_amount(invoice_text)
        print(f"Total Amount Detected: {total_amount}")
    else:
        print("No text found in the invoice.")
# Out:
# ...
#      <input type="file" id="files-3963210e-d354-48dc-8215-30de5d857fe6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3963210e-d354-48dc-8215-30de5d857fe6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: generate the code use scikit learn or tensorflow to train a machine learning algorithm like logistic regression, svm, knn for categorizing correctly accurate invoices based on extracted text data to classify into predefine categories groceries, clothes, electronics, services

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Sample data (replace with your actual invoice data)
data = {
    'invoice_text': [
        "Grocery items: Milk, Bread, Eggs. Total: $25",
        "Purchased a new shirt and pants. Total: $50",
        "Bought a laptop and mouse. Total: $800",
        "Internet service bill. Total: $60",
        "Groceries: Fruits, Vegetables, Chicken. Total: $40",
        "Bought a dress and shoes. Total: $75",
        "New TV and soundbar. Total: $1200",
        "Electricity bill. Total: $100"
    ],
    'category': [
        'groceries', 'clothes', 'electronics', 'services',
        'groceries', 'clothes', 'electronics', 'services'
    ]
}

df = pd.DataFrame(data)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    df['invoice_text'], df['category'], test_size=0.2, random_state=42
)

# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# Train a Logistic Regression model
model = LogisticRegression()
model.fit(X_train_vec, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test_vec)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
print(classification_report(y_test, y_pred))


# Example of how to predict the category for a new invoice
new_invoice_text = "Bought a new phone and headphones. Total: $500"
new_invoice_vec = vectorizer.transform([new_invoice_text])
predicted_category = model.predict(new_invoice_vec)[0]
print(f"Predicted Category for new invoice: {predicted_category}")
# Out:
# Accuracy: 0.0
#               precision    recall  f1-score   support
#
#      clothes       0.00      0.00      0.00       2.0
#  electronics       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
#
# Predicted Category for new invoice: electronics
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# Install required packages
# !pip install opencv-python-headless pytesseract
# !apt-get install -y poppler-utils  # Required for PDF to image conversion

import cv2
import pytesseract
import re
import numpy as np
from google.colab import files

# Function to preprocess the image for OCR
def preprocess_image(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
    return binary

# Function to extract text from the image using Tesseract OCR
def extract_text_from_image(image):
    processed_image = preprocess_image(image)
    text = pytesseract.image_to_string(processed_image)
    return text

# Function to detect total amount using regex
def detect_total_amount(text):
    # Regex pattern to match "Total: $Amount"
    pattern = r'Total\s*:\s*\$?\s*([0-9]+(?:\.[0-9]{1,2})?)'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(1)
    return None

# Upload a pre-recorded video or image
uploaded = files.upload()

# Load the uploaded video or image file
for filename in uploaded.keys():
    # Check if it's a video or an image
    if filename.endswith(('.mp4', '.avi', '.mov')):
        # Video processing
        video = cv2.VideoCapture(filename)
        ret, frame = video.read()  # Capture the first frame
        video.release()

        if ret:
            cv2.imwrite('frame.jpg', frame)  # Save the frame as an image
            image = frame
        else:
            print("Error capturing video frame.")
    else:
        # Image processing
        image = cv2.imread(filename)

# Extract text from the captured image
invoice_text = extract_text_from_image(image)

# Check if text extraction worked
if invoice_text:
    print("Extracted Text:\n", invoice_text)

    # Detect total amount from the extracted text
    total_amount = detect_total_amount(invoice_text)
    if total_amount:
        print(f"Total Amount Detected: {total_amount}")
    else:
        print("No total amount found.")
else:
    print("No text found in the invoice.")
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.5 [186 kB]
# Fetched 186 kB in 0s (441 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 123646 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.5_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.5) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.5) ...
# Processing triggers for man-db (2.10.2-1) ...
#      <input type="file" id="files-b6076348-4cf6-4f88-b804-9b5af014653f" name="files[]" multiple disabled
#         style="border:none" />
# ...

# %%
# !pip install pyimagesearch.alignment
# Out:
# ERROR: Could not find a version that satisfies the requirement pyimagesearch.alignment (from versions: none)
# ERROR: No matching distribution found for pyimagesearch.alignment

# %%
# !git clone https://github.com/PyImageSearch/imutils.git  # Use '!' to denote a shell command
# !pip install imutils/
# Out:
# Cloning into 'imutils'...
# remote: Enumerating objects: 688, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 688 (delta 1), reused 6 (delta 1), pack-reused 677 (from 1)
# Receiving objects: 100% (688/688), 6.88 MiB | 25.45 MiB/s, done.
# Resolving deltas: 100% (395/395), done.
# Processing ./imutils
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=26719 sha256=b23f8ca49a79577661865f6bb6cef0d4803978c40c2f618d1cb23f0584905755
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w0yh69hw/wheels/89/62/16/326cf045fbd9de284f6d4da4f25882e82cb935d4f1d1e5913c
# Successfully built imutils
# ...
#   Attempting uninstall: imutils
#     Found existing installation: imutils 0.5.4
#     Uninstalling imutils-0.5.4:
#       Successfully uninstalled imutils-0.5.4
# ...

# %%
# import the necessary packages
from pyimagesearch.alignment import align_images
from collections import namedtuple
import pytesseract
import argparse
import imutils
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-41feb59da64a> in <cell line: 2>()
#       1 # import the necessary packages
# ----> 2 from pyimagesearch.alignment import align_images
#       3 from collections import namedtuple
#       4 import pytesseract
#       5 import argparse
#
# ModuleNotFoundError: No module named 'pyimagesearch'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install imutils
# !git clone https://github.com/PyImageSearch/imutils.git
# Change the current directory to the cloned repository
# !cd imutils/alignment
# Install the package
# !pip install -e .

# import the necessary packages
from imutils.perspective import four_point_transform
from skimage.filters import threshold_local
import numpy as np
import argparse
import cv2
import imutils

# Add the rest of your code here for aligning images and performing OCR
# Out:
# ...
# fatal: destination path 'imutils' already exists and is not an empty directory.
# /bin/bash: line 1: cd: imutils/alignment: No such file or directory
# Obtaining file:///content
# ERROR: file:///content does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
import cv2
import numpy as np

img = cv2.imread('/content/Screenshot 2024-09-20 at 5.00.37 PM (2).png')

# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)

#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)

#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

#skew correction
def deskew(image):
    coords = np.column_stack(np.where(image > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

#template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED)

# %%
image = cv2.imread('/content/Screenshot 2024-09-20 at 5.00.37 PM (4).png')

gray = get_grayscale(image)
thresh = thresholding(gray)
opening = opening(gray)
canny = canny(gray)

# %%
import cv2
import pytesseract
from google.colab.patches import cv2_imshow # Import cv2_imshow from google.colab.patches

img = cv2.imread('/content/Screenshot 2024-09-20 at 5.00.37 PM (3).png')

h, w, c = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    b = b.split(' ')
    img = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)

cv2_imshow(img) # Use cv2_imshow instead of cv2.imshow
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1196x1560>
# -1

# %%
import cv2
import pytesseract
from pytesseract import Output

img = cv2.imread('/content/Screenshot 2024-09-20 at 5.00.37 PM (2).png')

d = pytesseract.image_to_data(img, output_type=Output.DICT)
print(d.keys())
# Out:
# dict_keys(['level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num', 'left', 'top', 'width', 'height', 'conf', 'text'])

# %%
import cv2
import pytesseract
from pytesseract import Output
from google.colab.patches import cv2_imshow # Import the cv2_imshow function


img = cv2.imread('/content/Screenshot 2024-09-20 at 5.00.37 PM (2).png')

d = pytesseract.image_to_data(img, output_type=Output.DICT)
print(d.keys())

n_boxes = len(d['text'])
for i in range(n_boxes):
    if int(d['conf'][i]) > 60:
        (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
        img = cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

cv2_imshow(img) # Use cv2_imshow here instead of cv2.imshow
cv2.waitKey(0)
# Out:
# dict_keys(['level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num', 'left', 'top', 'width', 'height', 'conf', 'text'])
# <PIL.Image.Image image mode=RGB size=1196x1560>
# -1

# %%
import cv2
import pytesseract
from pytesseract import Output
from google.colab.patches import cv2_imshow # Import the cv2_imshow function
import re

# Load the invoice image
img = cv2.imread('/content/Screenshot 2024-09-20 at 5.00.37 PM (2).png')

# Perform OCR on the image using Tesseract, and get output in dictionary format
d = pytesseract.image_to_data(img, output_type=Output.DICT)

# Debug: Print the keys of the dictionary
print(d.keys())

# Initialize variables to store the total amount
total_amount = None
pattern = r"\b\d{1,3}(?:,\d{3})*(?:\.\d{2})?\b"  # Regex to match currency-like patterns (e.g., 1,234.56)

# Extract text from the image and look for "Total" or "Amount"
n_boxes = len(d['text'])
for i in range(n_boxes):
    if int(d['conf'][i]) > 60:  # Only consider text with high confidence
        text = d['text'][i].strip().lower()
        # If 'total' or 'amount' is found in the text
        if 'total' in text or 'amount' in text:
            # Check if the next few elements contain the amount
            for j in range(i+1, min(i+5, n_boxes)):
                if int(d['conf'][j]) > 60:  # Only consider text with high confidence
                    potential_amount = d['text'][j]
                    # Use regex to check if it looks like a currency value
                    if re.match(pattern, potential_amount):
                        total_amount = potential_amount
                        break
            if total_amount:
                break

# Draw boxes around detected text with high confidence
for i in range(n_boxes):
    if int(d['conf'][i]) > 60:
        (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
        img = cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

# Display the image with rectangles drawn around detected text
cv2_imshow(img)

# Display the total amount detected
if total_amount:
    print(f"Total Amount Detected: {total_amount}")
else:
    print("No total amount found.")
# Out:
# dict_keys(['level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num', 'left', 'top', 'width', 'height', 'conf', 'text'])
# <PIL.Image.Image image mode=RGB size=1196x1560>
# No total amount found.

# %%
import re
import cv2
import pytesseract
from pytesseract import Output
from google.colab.patches import cv2_imshow

# Ensure the correct file path to your image
img = cv2.imread('/content/Screenshot 2024-09-20 at 5.00.37 PM (4).png')

# Check if the image is loaded correctly
if img is None:
    print("Error: Image not loaded properly. Check the file path.")
else:
    d = pytesseract.image_to_data(img, output_type=Output.DICT)
    keys = list(d.keys())

    date_pattern = r'^(0[1-9]|[12][0-9]|3[01])/(0[1-9]|1[012])/(19|20)\d\d'  # Corrected regex pattern
    n_boxes = len(d['text'])
    for i in range(n_boxes):
        if int(d['conf'][i]) > 60:
            if re.match(date_pattern, d['text'][i]):
                (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
                img = cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    cv2_imshow(img) # Use cv2_imshow for Google Colab
    cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1196x1560>

# %%
osd = pytesseract.image_to_osd(img)
angle = re.search('(?<=Rotate: )\d+', osd).group(0)

# Check if a match is found before calling group()
match = re.search('(?<=Script: )\w+', osd) # Modified regex to match word characters
if match:
  script = match.group(0)
  print("angle: ", angle)
  print("script: ", script)
else:
  print("Script information not found.")
# Out:
# angle:  0
# script:  Latin

# %%
angle: 90
script: "Latin"

# %%
custom_config = r'--oem 3 --psm 6 outputbase digits'
print(pytesseract.image_to_string(img, config=custom_config))
# Out:
# 2 0
# 7
# 0
# 444.445.459.
# 460.461462.463464 323307
# 465466.467.468469.470.471472473.474..
# 75.476477.478479480 -08
# 481482.483.491492.493-
# 226401
# .
# 49783 323307
# 00949783125
# 08
# 402-4170507-6103552 01-721112
# 23.08.2024 -01-297683823-2425
# -23.08.2024
# 031150
# .50-
# 931.36 2931.36187167.6421.099.00
# 023252325
# 85183020
# -
# -

# %%
custom_config = r'-c tessedit_char_whitelist=abcdefghijklmnopqrstuvwxyz --psm 6'
print(pytesseract.image_to_string(img, config=custom_config))
# Out:
# a m ao ni n faxnvoiceillofsupplycashemo
# wee riginalforecipient
# oldy illingddress
# ii radeepkumar
# khasranumbers kamaldeepousearutiagar
# n
# tateode
# illage
# haukapur
# ucknowttarradesh hippingddress
# in radeepkumar
# radeepkumar
# amaldeepousearutiagar
# o
# egistrationo n
# ynamicode tateode
# ayseeaee laceofsupply
# ee laceofdelivery
# eos
# rderumber invoiceumberk
# rderate nvoiceetailsk
# nvoiceate
# pa taxaxax fotal
# fiepeecintonoiceuntatlytlmoramont
# botirdopesrorulyirelessinararudswpto
# laytimeualicswithxechmsowatency
# eastodehargingechpacerey g
# zz
# amountinords
# onefhousandinetynineonly
# ori
# uthorizedignatory
# hethertaxispayableunderreversechargeo

# %%
custom_config = r'-c tessedit_char_blacklist=0123456789 --psm 6'
pytesseract.image_to_string(img, config=custom_config)
# Out:
# 'a m aZO ni nN Tax Invoice/Bill of Supply/Cash Memo\nwee) (Original for Recipient)\nSold By: Billing Address :\nCLICKTECH RETAIL PRIVATE LIMITED Pradeep Kumar\n*Khasra numbers:(P),(P),S(P), Kamaldeep House, Maruti Nagar\nG,,G,,, RAWATBHATA, RAJASTHAN, /\n,,G/,,,/,/,/,/,/,,, IN\n(P),/,/,/, /,, State/UT Code:O\nB ,B,(P), ,,(P) Village -\nBhaukapur,\nLucknow, Uttar Pradesh, Shipping Address :\nIN Pradeep Kumar\nPradeep Kumar\nKamaldeep House, Maruti Nagar\nPAN No:AAJCCQ/SE RAWATBHATA, RAJASTHAN, /\nGST Registration No:OAAJCCSEZS IN\nDynamic QR Code: State/UT Code:\nBayseeaee Place of supply: RAJASTHAN\nee Place of delivery:RAJASTHAN\neos\nOrder Number:-/- Invoice Number :LKO-/\nOrder Date:.. Invoice Details :UP-LKO-/-\nInvoice Date :..\npa \\Tax |Tax |Tax [Total\nfiepeecinton otter yt Amram\nboAt Airdopes / Pro Truly Wireless in Ear Ear Buds w/Up to O\nIHRS Playtime, Dual Mics with ENx™ Tech, S ms Low-Latency\nIBeast™ Mode, ASAP™ Charging, I|WP™ Tech(Space Grey) | %.| %g. | % |IGST| %. 
# ...

# %%
custom_config = r'-l eng --psm 6'
pytesseract.image_to_string(img, config=custom_config)
# Out:
# 'a m aZO ni nN Tax Invoice/Bill of Supply/Cash Memo\nwee) (Original for Recipient)\nSold By: Billing Address :\nCLICKTECH RETAIL PRIVATE LIMITED Pradeep Kumar\n*Khasra numbers:444(P),445(P),459(P), Kamaldeep House, Maruti Nagar\n460,461 ,462,463,464, RAWATBHATA, RAJASTHAN, 323307\n465,466,467,468,469,470,471,472,473,474,,, IN\n75(P),476,477,478, 479,480, State/UT Code:08\n481 ,482,483(P),491 ,492,493(P) Village -\nBhaukapur,\nLucknow, Uttar Pradesh, 226401 Shipping Address :\nIN Pradeep Kumar\nPradeep Kumar\nKamaldeep House, Maruti Nagar\nPAN No:AAJCC9783E RAWATBHATA, RAJASTHAN, 323307\nGST Registration No:09AAJCC9783E1Z5 IN\nDynamic QR Code: State/UT Code:08\nBayseeaee Place of supply: RAJASTHAN\nee Place of delivery:RAJASTHAN\neos\nOrder Number:402-4170507-6103552 Invoice Number :LKO1-721112\nOrder Date:23.08.2024 Invoice Details :UP-LKO1-297683823-2425\nInvoice Date :23.08.2024\npa \\Tax |Tax |Tax [Total\nfiepeecinton otter yt Amram\nboAt Airdopes 311 Pro Truly Wireless in Ear Ear
# ...

# %%
custom_config = r'-l grc+tha+eng --psm 6'
pytesseract.image_to_string(img, config=custom_config)
# Out:
# 'a m aZO ni nN Tax Invoice/Bill of Supply/Cash Memo\nwee) (Original for Recipient)\nSold By: Billing Address :\nCLICKTECH RETAIL PRIVATE LIMITED Pradeep Kumar\n*Khasra numbers:444(P),445(P),459(P), Kamaldeep House, Maruti Nagar\n460,461 ,462,463,464, RAWATBHATA, RAJASTHAN, 323307\n465,466,467,468,469,470,471,472,473,474,,, IN\n75(P),476,477,478, 479,480, State/UT Code:08\n481 ,482,483(P),491 ,492,493(P) Village -\nBhaukapur,\nLucknow, Uttar Pradesh, 226401 Shipping Address :\nIN Pradeep Kumar\nPradeep Kumar\nKamaldeep House, Maruti Nagar\nPAN No:AAJCC9783E RAWATBHATA, RAJASTHAN, 323307\nGST Registration No:09AAJCC9783E1Z5 IN\nDynamic QR Code: State/UT Code:08\nBayseeaee Place of supply: RAJASTHAN\nee Place of delivery:RAJASTHAN\neos\nOrder Number:402-4170507-6103552 Invoice Number :LKO1-721112\nOrder Date:23.08.2024 Invoice Details :UP-LKO1-297683823-2425\nInvoice Date :23.08.2024\npa \\Tax |Tax |Tax [Total\nfiepeecinton otter yt Amram\nboAt Airdopes 311 Pro Truly Wireless in Ear Ear
# ...

# %%
# !pip install langdetect
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 17.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993221 sha256=225e691153435bdedf64019aad35060f75bc09f43fc8c22a289d0e1949d3fa6f
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...

# %%
from langdetect import detect_langs

# %%
custom_config = r'-l eng+por --psm 6'
txt = pytesseract.image_to_string(img, config=custom_config)

from langdetect import detect_langs
detect_langs(txt)
# Out:
# [en:0.9999964720250178]

# %%
custom_config = r'-l eng+spa --psm 6'
txt = pytesseract.image_to_string(img, config=custom_config)

# %%
# prompt: I WANT TO KNOW TOTAL AMOUNT IN INVOICE

def detect_total_amount(text):
    # Regex pattern to match "Total: $Amount"
    pattern = r'Total\s*:\s*\$?\s*([0-9]+(?:\.[0-9]{1,2})?)'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(1)
    return None


img = cv2.imread('/content/Screenshot 2024-09-20 at 5.00.37 PM (4).png')  # Replace with your image path

if img is None:
    print("Error: Image not loaded properly. Check the file path.")
else:
    text = pytesseract.image_to_string(img)
    total_amount = detect_total_amount(text)

    if total_amount:
        print(f"Total Amount Detected: {total_amount}")
    else:
        print("No total amount found.")
# Out:
# No total amount found.
